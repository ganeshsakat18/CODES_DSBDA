# %%
import pandas as pd

# %%
df=pd.read_csv("adult.csv",header=None)

# %%
df.columns=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # Subsets

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %% [markdown]
# ## subset1

# %%
df_male=df[df['sex']==' Male'] #here mistake male has m capital and some space

# %%
df_male
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32557   40            Private  154374        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
df_female=df[df['sex']==' Female']

# %%
df_female
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# 6       49        Private  160187            9th              5
# 8       31        Private   45781        Masters             14
# 12      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32546   37        Private  198216     Assoc-acdm             12
# 32549   43      State-gov  255835   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race  \
# 4          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %% [markdown]
# ## subset2

# %%
df_black= df[df['race']==' Black']

# %%
df_black
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 3       53   Private  234721           11th              7
# 4       28   Private  338409      Bachelors             13
# 6       49   Private  160187            9th              5
# 10      37   Private  280464   Some-college             10
# 13      32   Private  205019     Assoc-acdm             12
# ...    ...       ...     ...            ...            ...
# 32521   33   Private  273243        HS-grad              9
# 32535   22   Private  325033           12th              8
# 32537   30   Private  345898        HS-grad              9
# 32538   38   Private  139180      Bachelors             13
# 32541   41         ?  202822        HS-grad              9
#
#                marital-status          occupation    relationship    race  \
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4          Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
df_White= df[df['race']==' White']

# %%
df_White
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 5       37            Private  284582      Masters             14
# 7       52   Self-emp-not-inc  209642      HS-grad              9
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df_islander= df[df['race']==' Asian-Pac-Islander']

# %%
df_islander
# Out:
#        age   workclass  fnlwgt      education  education-num  \
# 11      30   State-gov  141297      Bachelors             13
# 14      40     Private  121772      Assoc-voc             11
# 27      54           ?  180211   Some-college             10
# 93      30     Private  117747        HS-grad              9
# 139     49     Private   81973   Some-college             10
# ...    ...         ...     ...            ...            ...
# 32457   33     Private  139057        Masters             14
# 32486   24     Private  216984   Some-college             10
# 32531   30           ?   33811      Bachelors             13
# 32533   54     Private  337992      Bachelors             13
# 32553   32     Private  116138        Masters             14
#
#             marital-status        occupation    relationship  \
# 11      Married-civ-spouse    Prof-specialty         Husband
# 14      Married-civ-spouse      Craft-repair         Husband
# ...

# %% [markdown]
# ## Merge

# %%
df_merge=pd.concat([df_female,df_male])

# %%
df_merge
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 4       28   Private  338409      Bachelors             13
# 5       37   Private  284582        Masters             14
# 6       49   Private  160187            9th              5
# 8       31   Private   45781        Masters             14
# 12      23   Private  122272      Bachelors             13
# ...    ...       ...     ...            ...            ...
# 32553   32   Private  116138        Masters             14
# 32554   53   Private  321865        Masters             14
# 32555   22   Private  310152   Some-college             10
# 32557   40   Private  154374        HS-grad              9
# 32559   22   Private  201490        HS-grad              9
#
#                marital-status          occupation    relationship  \
# 4          Married-civ-spouse      Prof-specialty            Wife
# 5          Married-civ-spouse     Exec-managerial            Wife
# ...

# %% [markdown]
# ## sort

# %%
sorted=df.sort_values('age')

# %%
sorted
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 12318   17            Private  127366           11th              7
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status        occupation    relationship  \
# 12318        Never-married             Sales       Own-child
# ...

# %% [markdown]
# ## Melt

# %%
melt_df=pd.melt(df,id_vars=['workclass','education'],value_name='value',var_name='metrics')

# %%
melt_df
# Out:
#                 workclass    education metrics   value
# 0               State-gov    Bachelors     age      39
# 1        Self-emp-not-inc    Bachelors     age      50
# 2                 Private      HS-grad     age      38
# 3                 Private         11th     age      53
# 4                 Private    Bachelors     age      28
# ...                   ...          ...     ...     ...
# 423288            Private   Assoc-acdm  target   <=50K
# 423289            Private      HS-grad  target    >50K
# 423290            Private      HS-grad  target   <=50K
# 423291            Private      HS-grad  target   <=50K
# 423292       Self-emp-inc      HS-grad  target    >50K
#
# [423293 rows x 4 columns]

# %%
df['index']=range(1,len(df)+1)

# %%
melt_df1=pd.melt(df,id_vars='index',value_vars=['age','race'])

# %%
melt_df1
# Out:
#        index variable   value
# 0          1      age      39
# 1          2      age      50
# 2          3      age      38
# 3          4      age      53
# 4          5      age      28
# ...      ...      ...     ...
# 65117  32557     race   White
# 65118  32558     race   White
# 65119  32559     race   White
# 65120  32560     race   White
# 65121  32561     race   White
#
# [65122 rows x 3 columns]

# %% [markdown]
# # Casting

# %%
casting=pd.pivot_table(df,index=['workclass','education'], values='age' ,fill_value=0)

# %%
casting
# Out:
#                                   age
# workclass    education
#  ?            10th          33.980000
#               11th          32.372881
#               12th          30.975000
#               1st-4th       63.833333
#               5th-6th       53.966667
# ...                               ...
#  State-gov    Some-college  34.289231
#  Without-pay  7th-8th       65.000000
#               Assoc-acdm    62.000000
#               HS-grad       42.555556
#               Some-college  53.000000
#
# [117 rows x 1 columns]

# %%
# def clean(data):
#     for col in data:
#         df[col].fillna(method='ffill', inplace=True)
        
# clean(df)

# %%
# king=['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# le = LabelEncoder()
# for col in king:
#     if df[col].dtype == 'object':  # Check if the column is of object type (categorical)
#         df[col] = le.fit_transform(df[col])

# %%
# from scipy.stats import zscore
# # Calculate Z-score for each column
# z_scores = df1.apply(zscore)

# # Define threshold for outlier detection
# threshold = 3  # You can adjust this threshold based on your requirement

# # Identify outliers based on threshold
# outliers_df = df1[(z_scores > threshold) | (z_scores < -threshold)]

# # Delete outliers for each column
# cleaned_df = df1[~((z_scores > threshold) | (z_scores < -threshold)).any(axis=1)]

# %%
# df = df.dropna(subset=['cast'])

# %%
# subset5=pd.merge(subset4,subset2,on='comment',how='outer')
