# %%
import numpy as np
import pandas as pd

# %%
missing_values=['?',np.nan]

# %%
df=pd.read_csv("dataset_Facebook.csv",sep=';',na_values=missing_values) #here we used the seprater as the ;

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %% [markdown]
# ## Creating data subsets for type of post

# %% [markdown]
# ### First Method

# %% [markdown]
# #### Particular column diffrent states

# %%
#df_video=df["Type"]=="Video" #this shows only that two values we want to show all the value means all the columns
df_video=df[df['Type']=='Video']
df_video.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_link=df[df["Type"]=="Status"]
df_link.head(5)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %% [markdown]
# ### two different column

# %%
subset3=df[['Type','Category']] # this method we have to use the showing the more than one column

# %%
subset3
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
subset3.loc[0:4]#it is used when ask particular collumns limited number of the row
# Out:
#      Type  Category
# 0   Photo         2
# 1  Status         2
# 2   Photo         3
# 3   Photo         2
# 4   Photo         2

# %% [markdown]
# ###

# %% [markdown]
# ## loc and Iloc for introducing some conditions

# %% [markdown]
# ### loc

# %%
subset4=df.loc[0:4,'Category']

# %%
subset4
# Out:
# 0    2
# 1    2
# 2    3
# 3    2
# 4    2
# Name: Category, dtype: int64

# %%
subset5=df.iloc[0:4,0:3]

# %%
subset5
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ## Merge Operation

# %% [markdown]
# ### Method 1

# %%
df_merge=pd.concat([df_link,df_video])

# %%
df_merge
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
df_merge.shape
# Out:
# (52, 19)

# %%
df_link.shape
# Out:
# (45, 19)

# %%
df_video.shape
# Out:
# (7, 19)

# %% [markdown]
# ### method2

# %%
df_photo=df[df["Type"]=='Photo'].loc[0:4] #photo should be in cotetion

# %%
df_photo
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 2                     177                      113
# 3                    2211                      790
# ...

# %%
df_video1=df_video

# %%
df_video1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
# subset5=pd.merge(subset4,subset2,on='comment',how='outer')

# %% [markdown]
# ## Sorting

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df_sortoing=df.sort_values(by=['comment'])

# %%
df_sortoing
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 111            136736   Photo         1          10             6          8
# 276            126424   Photo         3           7             3          4
# 282            126345  Status         2           6             7         11
# 286            126141   Photo         1           6             5         11
# ..                ...     ...       ...         ...           ...        ...
# 228            131728   Photo         2           7             4          3
# 288            126141   Photo         1           6             4         12
# 168            135428   Photo         1           9             3         10
# 460             92507   Photo         3           2             1         13
# 244            130791   Photo         2           7             3          5
#
# ...

# %%
#for decreasing order
df_sortoing1=df.sort_values(by=['comment'],ascending=False)

# %% [markdown]
# ### Transpose

# %%
df_transpose=df.transpose()

# %%
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# ## RESHAPE Melting

# %%
df['Index']=range(1,len(df)+1)

# %%
df_melted=pd.melt(df,id_vars=['Type','Category'],value_name='value',var_name="metrics")

# %%
df_melted
# Out:
#         Type  Category           metrics     value
# 0      Photo         2  Page total likes  139441.0
# 1     Status         2  Page total likes  139441.0
# 2      Photo         3  Page total likes  139441.0
# 3      Photo         2  Page total likes  139441.0
# 4      Photo         2  Page total likes  139441.0
# ...      ...       ...               ...       ...
# 8995   Photo         3             Index     496.0
# 8996   Photo         2             Index     497.0
# 8997   Photo         1             Index     498.0
# 8998   Photo         3             Index     499.0
# 8999   Photo         2             Index     500.0
#
# [9000 rows x 4 columns]

# %% [markdown]
# ### Method2

# %% [raw]
# - this method is only used for the getting the only one column name as varaible and put ther values of that column as the vlaue  in the value

# %%
df_melted2=pd.melt(df,id_vars='Index',value_vars='Type')

# %%
df_melted2
# Out:
#      Index variable   value
# 0        1     Type   Photo
# 1        2     Type  Status
# 2        3     Type   Photo
# 3        4     Type   Photo
# 4        5     Type   Photo
# ..     ...      ...     ...
# 495    496     Type   Photo
# 496    497     Type   Photo
# 497    498     Type   Photo
# 498    499     Type   Photo
# 499    500     Type   Photo
#
# [500 rows x 3 columns]

# %%
casting = pd.pivot_table(df,index=['Type','Category'],values='like', fill_value = 0)

# %%
casting
# Out:
#                        like
# Type   Category
# Link   1          75.650000
#        2          32.000000
#        3          68.000000
# Photo  1         126.000000
#        2         235.857143
#        3         219.753333
# Status 1         136.333333
#        2         182.552632
#        3         151.500000
# Video  1         231.428571

# %%
# def clean(data):
#     for col in data:
#         df[col].fillna(method='ffill', inplace=True)
        
# clean(df)

# %%
# king=['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# le = LabelEncoder()
# for col in king:
#     if df[col].dtype == 'object':  # Check if the column is of object type (categorical)
#         df[col] = le.fit_transform(df[col])

# %%
# from scipy.stats import zscore
# # Calculate Z-score for each column
# z_scores = df1.apply(zscore)

# # Define threshold for outlier detection
# threshold = 3  # You can adjust this threshold based on your requirement

# # Identify outliers based on threshold
# outliers_df = df1[(z_scores > threshold) | (z_scores < -threshold)]

# # Delete outliers for each column
# cleaned_df = df1[~((z_scores > threshold) | (z_scores < -threshold)).any(axis=1)]

# %%
# df = df.dropna(subset=['cast'])
